# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('aladdinGraphTest.csv')
tree_df = pd.read_csv('aladdinTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Aladdin: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Aladdin: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('basketballGraphTest.csv')
tree_df = pd.read_csv('basketballTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Basketball: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Basketball: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import ScalarFormatter

# Load the CSV files
graph_df = pd.read_csv('briberyGraphTest.csv')
tree_df = pd.read_csv('briberyTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Bribery: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Bribery: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((5, 5))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('deerhunterGraphTest.csv')
tree_df = pd.read_csv('deerhunterTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Deerhunter: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Deerhunter: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('fantasyGraphTest.csv')
tree_df = pd.read_csv('fantasyTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Fantasy: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Fantasy: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('grammaGraphTest.csv')
tree_df = pd.read_csv('grammaTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Gramma: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Gramma: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('hospitalGraphTest.csv')
tree_df = pd.read_csv('hospitalTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Hospital: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Hospital: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator

# Load the CSV files
graph_df = pd.read_csv('jailbreakGraphTest.csv')
tree_df = pd.read_csv('jailbreakTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Jailbreak: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Jailbreak: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('loversGraphTest.csv')
tree_df = pd.read_csv('loversTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Lovers: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Lovers: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator

# Load the CSV files
graph_df = pd.read_csv('raidersGraphTest.csv')
tree_df = pd.read_csv('raidersTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Raiders: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Raiders: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import ScalarFormatter

# Load the CSV files
graph_df = pd.read_csv('secretagentGraphTest.csv')
tree_df = pd.read_csv('secretagentTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Secret Agent: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((3, 3))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Secret Agent: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('spaceGraphTest.csv')
tree_df = pd.read_csv('spaceTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Space: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Space: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# Load the CSV files
graph_df = pd.read_csv('treasureGraphTest.csv')
tree_df = pd.read_csv('treasureTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Treasure: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
plt.yscale('log')
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Treasure: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
plt.yscale('log')
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# Load the CSV files
graph_df = pd.read_csv('treasureGraphTest.csv')
tree_df = pd.read_csv('treasureTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Treasure: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Treasure: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))
ax.yaxis.set_major_formatter(formatter)
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('westernGraphTest.csv')
tree_df = pd.read_csv('westernTreeTest.csv')

# Plot Nodes Generated vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Generated Nodes"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Generated Nodes"], marker="o")
plt.title("Western: Nodes vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], marker="o")
plt.title("Western: Time (ms) vs Depth", fontsize=50)
plt.tick_params(axis='both', which='major', labelsize=50)
ax = plt.gca()
ax.yaxis.get_offset_text().set_size(40)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('briberyGraphTest.csv')
tree_df = pd.read_csv('briberyTreeTest.csv')

# Correct the column name in the tree DataFrame
tree_df.rename(columns={"Visided Nodes": "Visited Nodes"}, inplace=True)

# Plot Nodes Visited vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Visited Nodes"], label="Graph-Based Approach", marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Visited Nodes"], label="Tree-Based Approach", marker="o")
plt.xlabel("Depth Limit")
plt.ylabel("Visited Nodes")
plt.title("Bribery: Nodes Visited vs Depth Limit (Graph vs Tree)")
plt.legend()
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], label="Graph-Based Approach", marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], label="Tree-Based Approach", marker="o")
plt.xlabel("Depth Limit")
plt.ylabel("Time Taken (ms)")
plt.title("Bribery: Time Taken (ms) vs Depth Limit (Graph vs Tree)")
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files
graph_df = pd.read_csv('secretagentGraphTest.csv')
tree_df = pd.read_csv('secretagentTreeTest.csv')

# Correct the column name in the tree DataFrame
tree_df.rename(columns={"Visided Nodes": "Visited Nodes"}, inplace=True)

# Plot Nodes Visited vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Visited Nodes"], label="Graph-Based Approach", marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Visited Nodes"], label="Tree-Based Approach", marker="o")
plt.xlabel("Depth Limit")
plt.ylabel("Visited Nodes")
plt.title("Secret Agent: Nodes Visited vs Depth Limit (Graph vs Tree)")
plt.legend()
plt.grid(True)
plt.show()

# Plot Time Taken (ms) vs Depth Limit
plt.figure(figsize=(12, 6))
plt.plot(graph_df["Depth Limit"], graph_df["Time Taken (ms)"], label="Graph-Based Approach", marker="o")
plt.plot(tree_df["Depth Limit"], tree_df["Time Taken (ms)"], label="Tree-Based Approach", marker="o")
plt.xlabel("Depth Limit")
plt.ylabel("Time Taken (ms)")
plt.title("Secret Agent: Time Taken (ms) vs Depth Limit (Graph vs Tree)")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
import csv

# Dataset
x = []
y = []
x1 = []
y1 = []
with open('graphTestRaiders.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    next(lines)  # Skip the first row (header)
    for row in lines:
        x.append(float(row[0]))
        y.append(float(row[1]))
X_Y_Spline = make_interp_spline(x, y)        
with open('treeTestRaiders.csv','r') as csvfile:
    lines1 = csv.reader(csvfile, delimiter=',')
    next(lines1)  # Skip the first row (header)
    for row1 in lines1:
        x1.append(float(row1[0]))
        y1.append(float(row1[1]))
X1_Y1_Spline = make_interp_spline(x1, y1)

# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(min(x), max(x), 500)
Y_ = X_Y_Spline(X_)
X1_ = np.linspace(min(x1), max(x1), 500)
Y1_ = X1_Y1_Spline(X1_)
# Plotting the Graph
plt.plot(X_, Y_)
plt.plot(X1_, Y1_)
plt.title("Nodes Visited for Tree Based (Orange) vs Graph Based (Blue) Solution on Raiders")
plt.xlabel("Depth")
plt.ylabel("Visited Nodes")
plt.show()

# %%
import numpy as np
import numpy as np
from scipy.interpolate import make_interp_spline
import matplotlib.pyplot as plt
import csv

# Dataset
x = []
y = []
x1 = []
y1 = []
with open('graphTestRaiders.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    next(lines)  # Skip the first row (header)
    for row in lines:
        x.append(float(row[0]))
        y.append(float(row[2]))

X_Y_Spline = make_interp_spline(x, y)
with open('treeTestRaiders.csv','r') as csvfile:
    lines1 = csv.reader(csvfile, delimiter=',')
    next(lines1)  # Skip the first row (header)
    for row1 in lines1:
        x1.append(float(row1[0]))
        y1.append(float(row1[2]))
X1_Y1_Spline = make_interp_spline(x1, y1)

# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(min(x), max(x), 500)
Y_ = X_Y_Spline(X_)
X1_ = np.linspace(min(x1), max(x1), 500)
Y1_ = X1_Y1_Spline(X1_)


# Plotting the Graph
plt.plot(X_, Y_)
plt.plot(X1_, Y1_)
plt.title("Time Taken for Tree Based (Orange) vs Graph Based (Blue) Solution on Raiders")
plt.xlabel("Depth")
plt.ylabel("Time (ms)")
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([], [], label='Tree Search', color='tab:orange', marker='o')
ax.plot([], [], label='Graph Search', color='tab:blue', marker='o')
legend = ax.legend(loc='center', frameon=False, fontsize=14)
ax.axis('off')
plt.savefig('legend.JPG', dpi=300, bbox_inches='tight')
